# %% [markdown]
# ### **Notebook du Projet Olist — Pipeline BSG (Bronze → Silver → Gold)**
#
# **Objectifs du notebook :**\
#   • Explorer ou visualiser les données (selon le numéro).\
#   • Charger les fonctions du projet via `import src....`\
#   • Travailler uniquement avec les données validées (Silver ou Gold).\
#   • Ne jamais réaliser de nettoyage manuel ici.\
#   • Produire des analyses ou visualisations reproductibles.
#
# **Rappel des bonnes pratiques :**\
#   • Toujours recharger les modules après modification : importlib.reload(...)\
#   • Ne jamais dupliquer du code du pipeline dans les notebooks.\
#   • Utiliser les schémas Pandera pour vérifier la qualité si besoin.
